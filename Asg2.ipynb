# %% [markdown]
# <a href="https://colab.research.google.com/github/SuchiraSumon/MobileAsg2/blob/main/Asg2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyngrok==4.1.1
# !pip install flask-ngrok
# !ngrok authtoken '2XYJrp9BOVMzD0aJ3oCDTanr1vr_5s5d52jWcqnfkbZpcyBM9'
# Out:
# Collecting pyngrok==4.1.1
#   Downloading pyngrok-4.1.1.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pyngrok==4.1.1) (0.18.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyngrok==4.1.1) (6.0.1)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15963 sha256=f6f9a54b2478600fae07c6582cd749678c0f5a64870dad5a6590b8189a1cd5aa
#   Stored in directory: /root/.cache/pip/wheels/4c/7c/4c/632fba2ea8e88d8890102eb07bc922e1ca8fa14db5902c91a8
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-4.1.1
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.10/dist-packages (from flask-ngrok) (2.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from flask-ngrok) (2.31.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.8->flask-ngrok) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.8->flask-ngrok) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.8->flask-ngrok) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=0.8->flask-ngrok) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->flask-ngrok) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->flask-ngrok) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->flask-ngrok) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->flask-ngrok) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask>=0.8->flask-ngrok) (2.1.3)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sqlite3
from flask import Flask, render_template, request, redirect, url_for
from flask_ngrok import run_with_ngrok

import sys
sys.path.append('/content/drive/MyDrive/Mobile Asg 2')

from hobby_model import HobbyModel
#from person_model import Person

# Connect to SQLite database
db_path = '/content/drive/MyDrive/Mobile Asg 2/mydatabase.db'

templates_folder = '/content/drive/MyDrive/Mobile Asg 2/templates'
static_folder = '/content/drive/MyDrive/Mobile Asg 2/static'

app = Flask(__name__, template_folder=templates_folder, static_folder=static_folder)
run_with_ngrok(app)

# Function to get a connection and cursor
def get_db():
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    return conn, cursor

# Function to close the connection
def close_db(conn):
    conn.close()

@app.route("/")
def hello_world():
    return render_template("index.html")

@app.route("/main-page")
def mainpage():
    return render_template("main-page.html")

@app.route("/hobby")
def hobby():
    students = HobbyModel.get_students()
    return render_template('hobby.html', students=students)

@app.route('/hobby/<int:student_id>')
def show_hobby(student_id):
    student = HobbyModel.get_student(student_id)

    if student:
        return render_template('hobby.html', students=[student])  # Wrap the student in a list
    else:
        return render_template('hobby.html', students=[])  # Render an empty list if student is not found

@app.route("/portfolio")
def portfolio():
    return render_template("portfolio.html")

@app.route("/contact", methods=['GET', 'POST'])
def contact():
    if request.method == 'POST':
        # Handle contact form submission here
        name = request.form.get('name')
        email = request.form.get('email')
        subject = request.form.get('subject')
        message = request.form.get('message')

        # Insert form data into the SQLite database
        insert_query = '''
        INSERT INTO form_submissions (name, email, subject, message)
        VALUES (?, ?, ?, ?)
        '''
        form_data = (name, email, subject, message)

        # Get connection and cursor
        conn, cursor = get_db()

        # Execute the query
        cursor.execute(insert_query, form_data)

        # Commit the changes and close the connection
        conn.commit()
        close_db(conn)

        # Redirect to a thank you page
        return redirect(url_for('thank_you'))

    return render_template("contact.html")

@app.route("/thank-you")
def thank_you():
    return render_template("thank-you.html")

@app.route("/view-data")
def view_data():
    # Retrieve data from the SQLite database
    select_query = '''
    SELECT name, email, subject, message
    FROM form_submissions
    '''

    # Get connection and cursor
    conn, cursor = get_db()

    # Execute the query
    cursor.execute(select_query)

    # Fetch all records
    data = cursor.fetchall()

    # Close the connection
    close_db(conn)

    # Render a template to display the data
    return render_template("view-data.html", data=data)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://0e1a-34-74-28-52.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:18] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/js/main.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/images/thivya.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/css/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/images/chira.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/aos/aos.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/php-email-form/validate.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/waypoints/noframework.waypoints.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/images/ezu.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/aos/aos.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:19] "GET /static/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:24] "GET /static/vendor/bootstrap-icons/fonts/bootstrap-icons.woff2?2820a3852bdb9a5832199cc61cec4e65 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:26] "GET /static/images/favicon.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:43] "GET /main-page HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/aos/aos.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/waypoints/noframework.waypoints.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/images/chira.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/aos/aos.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/css/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/js/main.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/images/thivya.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/images/ezu.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:38:44] "GET /static/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:00] "GET /portfolio HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/aos/aos.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /assets/img/about.jpg HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/css/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/images/thivya.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/images/about.jpg HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/images/ezu.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/images/chira.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/waypoints/noframework.waypoints.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/vendor/aos/aos.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:01] "GET /static/js/main.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /hobby/3 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/images/chira.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/aos/aos.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/css/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/aos/aos.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/waypoints/noframework.waypoints.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/js/main.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:16] "GET /static/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:17] "GET /static/vendor/boxicons/fonts/boxicons.woff2 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:31] "GET /hobby/1 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/aos/aos.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/aos/aos.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/images/ezu.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/js/main.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/css/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/waypoints/noframework.waypoints.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:32] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:41] "GET /hobby/2 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/aos/aos.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/css/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/waypoints/noframework.waypoints.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/images/thivya.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/js/main.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/aos/aos.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:42] "GET /static/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /contact HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/images/chira.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/css/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/images/thivya.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/js/main.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/images/ezu.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/vendor/aos/aos.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:55] "GET /static/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:56] "GET /static/vendor/aos/aos.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:56] "GET /static/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:56] "GET /static/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:56] "GET /static/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:56] "GET /static/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:56] "GET /static/vendor/waypoints/noframework.waypoints.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [16/Jan/2024 16:39:56] "GET /static/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
